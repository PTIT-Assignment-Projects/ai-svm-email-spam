# %% [markdown]
# # Import thư viện

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
result_path = '/content/drive/MyDrive/Colab Notebooks/PTIT/AI'
folder_path = '/content/drive/MyDrive/Colab Notebooks/PTIT/AI/result'
hardmargin_svm_tfidf='hardmargin_svm_tfidf'
svm_pegasos = 'svm_pegasos'
base_svm_tfidf='base_svm_tfidf'

# %%
# @title
a = [i for i in range(1000, 10000, 500)]
b = [i for i in range(1500, 5500, 500)]
c = [i for i in range(1000, 5500, 500)]
dataframes = []
df = pd.read_csv(os.path.join(folder_path, f'{hardmargin_svm_tfidf}_1000.csv'))
dataframes.append(df)
for i in b:
    df1 = pd.read_csv(os.path.join(folder_path, f'{hardmargin_svm_tfidf}_{i}.csv'))
    dataframes.append(df1)
for i in a:
    df3 = pd.read_csv(os.path.join(folder_path, f'{base_svm_tfidf}_{i}.csv'))
    dataframes.append(df1)
    dataframes.append(df3)
combined_df = pd.concat(dataframes, ignore_index=True)
combined_df.to_csv(os.path.join(result_path, f'combined_time_svm.csv'), index=False)

# %%
# @title
a = [i for i in range(1000, 10000, 500)]
b = [i for i in range(1500, 5500, 500)]
c = [i for i in range(1000, 5500, 500)]
dataframes = []
df = pd.read_csv(os.path.join(folder_path, f'{hardmargin_svm_tfidf}_1000.csv'))
dataframes.append(df)
for i in b:
    df1 = pd.read_csv(os.path.join(folder_path, f'{hardmargin_svm_tfidf}_{i}.csv'))
    dataframes.append(df1)
for i in a:
    df3 = pd.read_csv(os.path.join(folder_path, f'{base_svm_tfidf}_{i}.csv'))
    df4 = pd.read_csv(os.path.join(folder_path, f'{svm_pegasos}_{i}.csv'))
    dataframes.append(df1)
    dataframes.append(df3)
    dataframes.append(df4)
combined_df = pd.concat(dataframes, ignore_index=True)
combined_df.to_csv(os.path.join(folder_path, f'combined_time_svm_after_pegasos.csv'), index=False)

# %% [markdown]
# # Load data so sánh HardMarginSVM

# %%
df = pd.read_csv(os.path.join(result_path, f'combined_time_svm.csv'))
df.head()
# Out:
#             class_name         time  accuracy_score  f1_score     n
# 0  HardMarginSVM_tfidf   188.271099        0.945000  0.946860  1000
# 1  HardMarginSVM_tfidf   483.728427        0.960000  0.963415  1500
# 2  HardMarginSVM_tfidf  1025.564333        0.960000  0.961353  2000
# 3  HardMarginSVM_tfidf  1769.558942        0.976000  0.976378  2500
# 4  HardMarginSVM_tfidf  2834.332839        0.966667  0.966887  3000

# %% [markdown]
# ## Visualize

# %% [markdown]
# ### n vs time

# %%
sns.lineplot( x = "n", y = "time",hue = 'class_name',data = df);

# %%
sns.lineplot( x = "n", y = "time",hue = 'class_name',data = df[(df['n'] <= 5000)]);

# %% [markdown]
# ### n vs accuracy

# %%
sns.lineplot( x = "n", y = "accuracy_score",hue = 'class_name',data = df);

# %%
sns.lineplot( x = "n", y = "accuracy_score",hue = 'class_name',data = df[df['n'] <= 5000]);

# %% [markdown]
# ### n vs f1 score

# %%
sns.lineplot( x = "n", y = "f1_score",hue = 'class_name',data = df);

# %%
sns.lineplot( x = "n", y = "f1_score",hue = 'class_name',data = df[df['n'] <= 5000]);

# %% [markdown]
# ### time vs accuracy_score

# %%
sns.lineplot( x = "time", y = "accuracy_score",hue = 'class_name',data = df);

# %% [markdown]
# # Load data so sánh HardMarginSVM và SVM_pegasos

# %%
df = pd.read_csv(os.path.join(folder_path, f'combined_time_svm_after_pegasos.csv'))
df.head()
# Out:
#             class_name         time  accuracy_score  f1_score     n
# 0  HardMarginSVM_tfidf   188.271099        0.945000  0.946860  1000
# 1  HardMarginSVM_tfidf   483.728427        0.960000  0.963415  1500
# 2  HardMarginSVM_tfidf  1025.564333        0.960000  0.961353  2000
# 3  HardMarginSVM_tfidf  1769.558942        0.976000  0.976378  2500
# 4  HardMarginSVM_tfidf  2834.332839        0.966667  0.966887  3000

# %% [markdown]
# ## Visualize

# %% [markdown]
# ### n vs time

# %%
sns.lineplot( x = "n", y = "time",hue = 'class_name',data = df);

# %%
sns.lineplot( x = "n", y = "time",hue = 'class_name',data = df[df['class_name'] != 'HardMarginSVM_tfidf']);

# %% [markdown]
# ### n vs accuracy

# %%
sns.lineplot( x = "n", y = "accuracy_score",hue = 'class_name',data = df[df['n'] <= 5000]);

# %%
sns.lineplot( x = "n", y = "accuracy_score",hue = 'class_name',data = df[df['class_name'] != 'HardMarginSVM_tfidf']);
